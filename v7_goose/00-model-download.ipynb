# %% [markdown]
# # Downloads the reference 1.5B world model
#
# Run this before any other notebooks

# %%
# !mkdir -p "./.model"
# !wget -nc "https://huggingface.co/BlinkDL/rwkv-7-world/resolve/main/RWKV-x070-World-1.5B-v3-20250127-ctx4096.pth" -O "./.model/v7-1B5-world.pth"
# Out:
# --2025-02-09 20:35:33--  https://huggingface.co/BlinkDL/rwkv-7-world/resolve/0629eb5928f9e929b27d1e95dd57d124d249ce6b/RWKV-x070-World-1.5B-v3-20250127-ctx4096.pth
# Resolving huggingface.co (huggingface.co)... 18.155.192.9, 18.155.192.4, 18.155.192.67, ...
# Connecting to huggingface.co (huggingface.co)|18.155.192.9|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !mkdir -p "./.model"
# !wget -nc "https://huggingface.co/BlinkDL/rwkv-7-world/resolve/main/RWKV-x070-World-2.9B-v3-20250211-ctx4096.pth" -O "./.model/v7-2B9-world.pth"
# Out:
# --2025-03-16 06:30:54--  https://huggingface.co/BlinkDL/rwkv-7-world/resolve/main/RWKV-x070-World-2.9B-v3-20250211-ctx4096.pth
# Resolving huggingface.co (huggingface.co)... 3.168.86.96, 3.168.86.127, 3.168.86.111, ...
# Connecting to huggingface.co (huggingface.co)|3.168.86.96|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...
