# %%
# !mkdir -p "./.model"
# !wget -nc "https://huggingface.co/RWKV/v6-Finch-PTH/resolve/main/RWKV-Finch-1B6.pth" -O "./.model/v6-1B6.pth"
# Out:
# --2025-03-15 17:47:22--  https://huggingface.co/RWKV/v6-Finch-PTH/resolve/main/RWKV-Finch-1B6.pth
# Resolving huggingface.co (huggingface.co)... 3.168.86.111, 3.168.86.52, 3.168.86.96, ...
# Connecting to huggingface.co (huggingface.co)|3.168.86.111|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !mkdir -p "./.model"
# !wget -nc "https://huggingface.co/RWKV/v6-Finch-PTH/resolve/main/RWKV-Finch-7B.pth" -O "./.model/v6-7B.pth"
# Out:
# --2025-03-14 22:20:54--  https://huggingface.co/RWKV/v6-Finch-PTH/resolve/main/RWKV-Finch-7B.pth
# Resolving huggingface.co (huggingface.co)... 3.168.86.52, 3.168.86.127, 3.168.86.96, ...
# Connecting to huggingface.co (huggingface.co)|3.168.86.52|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...
