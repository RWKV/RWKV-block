# %%
# !./run_gpt2_test.sh
# Out:
# Running GPT2 test with configuration: /Users/picocreator/Desktop/Recursal/rwkv-prj/RWKV-block/test/hf_trainer/train_gpt2/test_config.jsonc
# Output directory: /Users/picocreator/Desktop/Recursal/rwkv-prj/RWKV-block/test/hf_trainer/train_gpt2/output
# 2025-03-16 13:29:51 - root - INFO - Loading configuration from /Users/picocreator/Desktop/Recursal/rwkv-prj/RWKV-block/test/hf_trainer/train_gpt2/test_config.jsonc
# 2025-03-16 13:29:51 - root - INFO - Trainable weights saving mode enabled: Only trainable weights will be saved in checkpoints
# 2025-03-16 13:29:51 - root - WARNING - CUDA is not available. Training will be slow on CPU.
# 2025-03-16 13:29:51 - model_utils - INFO - Loading model and tokenizer from gpt2
# 2025-03-16 13:29:52 - model_utils - INFO - CUDA not available, using CPU for training
# 2025-03-16 13:29:52 - model_utils - INFO - Model loaded: GPT2LMHeadModel
# 2025-03-16 13:29:52 - model_utils - INFO - Tokenizer loaded: GPT2TokenizerFast
# ...
